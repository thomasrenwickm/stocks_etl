# %%
import requests
import os
from dotenv import load_dotenv
import json

# %% [markdown]
# ## Calling the API

# %%
load_dotenv()
API_KEY =  os.getenv("API_KEY")

# %%
base_url = "https://backend.simfin.com/api/v3/companies/general/compact?ticker=AAPL"
endpoint_url = f"{base_url}"

headers = {
    "accept": "application/json",
    "Authorization": f"{API_KEY}"
}

response = requests.get(endpoint_url, headers=headers)

if response.status_code == 200:
    # Parse the JSON response
    data = response.json()
else:
    print(f"Failed to retrieve data. Status code: {response.status_code}")

# %% [markdown]
# ## Creating the API wrapper
# I need to study OOP --> will help me with this

# %%
class PySimFin

# %% [markdown]
# ## Exploration

# %%
data['columns']
# Out:
# ['companyDescription',
#  'endFy',
#  'id',
#  'industryName',
#  'isin',
#  'market',
#  'name',
#  'numEmployees',
#  'sectorCode',
#  'sectorName',
#  'ticker']

# %%
data['data'][0]
# Out:
# ['Apple Inc is an American multinational technology company. It designs, manufactures, and markets mobile communication and media devices, personal computers, and portable digital music players.',
#  9,
#  111052,
#  'Technology',
#  'US0378331005',
#  'US',
#  'APPLE INC',
#  147000,
#  101001,
#  'Computer Hardware',
#  'AAPL']
